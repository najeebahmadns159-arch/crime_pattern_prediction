# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df=pd.read_csv('crime_in_la.csv')

# %% [markdown]
# ### DATASET INFORMATION

# %%
df.head()
# Out:
#        DR_NO    DATE OCC TIME OCC  AREA  AREA NAME  Rpt Dist No  Crm Cd  \
# 0  190326475  01/03/2020    21:30     7   Wilshire          784     510
# 1  200106753  08/02/2020    18:00     1    Central          182     330
# 2  200320258  04/11/2020    17:00     3  Southwest          356     480
# 3  200907217  10/03/2020    20:37     9   Van Nuys          964     343
# 4  220614831  17/08/2020    12:00     6  Hollywood          666     354
#
#                                 Crm Cd Desc              Mocodes  Vict Age  \
# 0                          VEHICLE - STOLEN                    0         0
# 1                     BURGLARY FROM VEHICLE       1822 1402 0344        47
# 2                             BIKE - STOLEN            0344 1251        19
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501        19
# 4                         THEFT OF IDENTITY  1822 1501 0930 2004        28
#
#   Vict Sex Vict Descent                                   Premis Desc  \
# ...

# %%
df.isnull().sum()
# Out:
# DR_NO               0
# DATE OCC            0
# TIME OCC            0
# AREA                0
# AREA NAME           0
# Rpt Dist No         0
# Crm Cd              0
# Crm Cd Desc         0
# Mocodes             0
# Vict Age            0
# Vict Sex            0
# Vict Descent        0
# Premis Desc       575
# Weapon Used Cd      0
# Weapon Desc         0
# Status              1
# Status Desc         0
# LOCATION            0
# LAT                 0
# LON                 0
# dtype: int64

# %%
df.dtypes
# Out:
# DR_NO               int64
# DATE OCC              str
# TIME OCC              str
# AREA                int64
# AREA NAME             str
# Rpt Dist No         int64
# Crm Cd              int64
# Crm Cd Desc           str
# Mocodes               str
# Vict Age            int64
# Vict Sex              str
# Vict Descent          str
# Premis Desc           str
# Weapon Used Cd    float64
# Weapon Desc           str
# Status                str
# Status Desc           str
# LOCATION              str
# LAT               float64
# LON               float64
# dtype: object

# %%
df.describe()
# Out:
#               DR_NO           AREA    Rpt Dist No         Crm Cd  \
# count  9.630060e+05  963006.000000  963006.000000  963006.000000
# mean   2.193097e+08      10.712636    1117.702063     500.660494
# std    1.271527e+07       6.102611     610.332012     206.634328
# min    8.170000e+02       1.000000     101.000000     110.000000
# 25%    2.105155e+08       6.000000     615.000000     331.000000
# 50%    2.207157e+08      11.000000    1141.000000     442.000000
# 75%    2.308096e+08      16.000000    1617.000000     626.000000
# max    2.499187e+08      21.000000    2199.000000     956.000000
#
#             Vict Age  Weapon Used Cd            LAT            LON
# count  963006.000000   963006.000000  963006.000000  963006.000000
# mean       29.296909      453.974850      33.994096    -118.076735
# std        21.926341       96.518319       1.653217       5.730322
# min        -4.000000      101.000000       0.000000    -118.667600
# ...

# %%
df[['Premis Desc']]
# Out:
#                                          Premis Desc
# 0                                             STREET
# 1                  BUS STOP/LAYOVER (ALSO QUERY 124)
# 2       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3                                     CLOTHING STORE
# 4                                           SIDEWALK
# ...                                              ...
# 963001                                      DRIVEWAY
# 963002                                      BUS STOP
# 963003                                         HOTEL
# 963004                MTA - ORANGE LINE - CHATSWORTH
# 963005                                      SIDEWALK
#
# [963006 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['DR_NO', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No',
#        'Crm Cd', 'Crm Cd Desc', 'Mocodes', 'Vict Age', 'Vict Sex',
#        'Vict Descent', 'Premis Desc', 'Weapon Used Cd', 'Weapon Desc',
#        'Status', 'Status Desc', 'LOCATION', 'LAT', 'LON'],
#       dtype='str')

# %%
df_copy=df.drop(['DR_NO','Status','Status Desc','LOCATION','Mocodes','Crm Cd' ,'AREA' ],axis=1)

# %%
df_copy.head()
# Out:
#      DATE OCC TIME OCC  AREA NAME  Rpt Dist No  \
# 0  01/03/2020    21:30   Wilshire          784
# 1  08/02/2020    18:00    Central          182
# 2  04/11/2020    17:00  Southwest          356
# 3  10/03/2020    20:37   Van Nuys          964
# 4  17/08/2020    12:00  Hollywood          666
#
#                                 Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0                          VEHICLE - STOLEN         0        M            O
# 1                     BURGLARY FROM VEHICLE        47        M            O
# 2                             BIKE - STOLEN        19        X            X
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)        19        M            O
# 4                         THEFT OF IDENTITY        28        M            H
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                                        STREET           500.0
# 1             BUS STOP/LAYOVER (ALSO QUERY 124)           500.0
# ...

# %%
df_copy['Vict Age'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### EXPLORATORY DATA ABALYSIS

# %%
df_copy['DATE OCC'] = pd.to_datetime(df_copy['DATE OCC'], errors='coerce')

df_copy['year'] = df_copy['DATE OCC'].dt.year
df_copy['month'] = df_copy['DATE OCC'].dt.month
df_copy['day'] = df_copy['DATE OCC'].dt.day

# %%
df_copy.head()
# Out:
#     DATE OCC TIME OCC  AREA NAME  Rpt Dist No  \
# 0 2020-01-03    21:30   Wilshire          784
# 1 2020-08-02    18:00    Central          182
# 2 2020-04-11    17:00  Southwest          356
# 3 2020-10-03    20:37   Van Nuys          964
# 4        NaT    12:00  Hollywood          666
#
#                                 Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0                          VEHICLE - STOLEN         0        M            O
# 1                     BURGLARY FROM VEHICLE        47        M            O
# 2                             BIKE - STOLEN        19        X            X
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)        19        M            O
# 4                         THEFT OF IDENTITY        28        M            H
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                                        STREET           500.0
# 1             BUS STOP/LAYOVER (ALSO QUERY 124)           500.0
# ...

# %%
df_copy=df_copy.drop(['DATE OCC'],axis=1)

# %%
df_copy['TIME OCC'] = pd.to_datetime(df_copy['TIME OCC'], format='%H:%M', errors='coerce')
df_copy['hour'] = df_copy['TIME OCC'].dt.hour
df_copy['minute'] = df_copy['TIME OCC'].dt.minute

# %%
df_copy.head()
# Out:
#              TIME OCC  AREA NAME  Rpt Dist No  \
# 0 1900-01-01 21:30:00   Wilshire          784
# 1 1900-01-01 18:00:00    Central          182
# 2 1900-01-01 17:00:00  Southwest          356
# 3 1900-01-01 20:37:00   Van Nuys          964
# 4 1900-01-01 12:00:00  Hollywood          666
#
#                                 Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0                          VEHICLE - STOLEN         0        M            O
# 1                     BURGLARY FROM VEHICLE        47        M            O
# 2                             BIKE - STOLEN        19        X            X
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)        19        M            O
# 4                         THEFT OF IDENTITY        28        M            H
#
#                                     Premis Desc  Weapon Used Cd  \
# 0                                        STREET           500.0
# 1             BUS STOP/LAYOVER (ALSO QUERY 124)           500.0
# ...

# %%
df_copy=df_copy.drop(['TIME OCC'],axis=1)

# %%
df_copy
# Out:
#          AREA NAME  Rpt Dist No  \
# 0         Wilshire          784
# 1          Central          182
# 2        Southwest          356
# 3         Van Nuys          964
# 4        Hollywood          666
# ...            ...          ...
# 963001     Topanga         2103
# 963002     Olympic         2013
# 963003     Central          101
# 963004  Devonshire         1751
# 963005   Southwest          358
#
#                                             Crm Cd Desc  Vict Age Vict Sex  \
# 0                                      VEHICLE - STOLEN         0        M
# 1                                 BURGLARY FROM VEHICLE        47        M
# 2                                         BIKE - STOLEN        19        X
# 3              SHOPLIFTING-GRAND THEFT ($950.01 & OVER)        19        M
# 4                                     THEFT OF IDENTITY        28        M
# ...                                                 ...       ...      ...
# ...

# %%
df_copy.isnull().sum()
# Out:
# AREA NAME              0
# Rpt Dist No            0
# Crm Cd Desc            0
# Vict Age               0
# Vict Sex               0
# Vict Descent           0
# Premis Desc          575
# Weapon Used Cd         0
# Weapon Desc            0
# LAT                    0
# LON                    0
# year              567144
# month             567144
# day               567144
# hour                   0
# minute                 0
# dtype: int64

# %%
df_copy['year'].nunique()
# Out:
# 5

# %%
df_copy.shape
# Out:
# (963006, 16)

# %%
(df_copy['year'].isna().sum() / len(df)) * 100
# Out:
# np.float64(58.89309100877876)

# %%
df_copy[['year','month','day']].isnull().mean() * 100
# Out:
# year     58.893091
# month    58.893091
# day      58.893091
# dtype: float64

# %%
for col in ['year', 'month', 'day']:
    df_copy[col] = df_copy.groupby(['AREA NAME', 'hour'])[col]\
                .transform(lambda x: x.fillna(x.mode()[0] if not x.mode().empty else x))

# %%
for col in ['year', 'month', 'day']:
    df_copy[col] = df_copy[col].fillna(df_copy[col].mode()[0])

# %%
df_copy.isnull().sum()
# Out:
# AREA NAME           0
# Rpt Dist No         0
# Crm Cd Desc         0
# Vict Age            0
# Vict Sex            0
# Vict Descent        0
# Premis Desc       575
# Weapon Used Cd      0
# Weapon Desc         0
# LAT                 0
# LON                 0
# year                0
# month               0
# day                 0
# hour                0
# minute              0
# dtype: int64

# %%
(df_copy['Premis Desc'].isna().sum() / len(df)) * 100
# Out:
# np.float64(0.05970886993435139)

# %%
df_copy['Premis Desc'] = df_copy['Premis Desc'].fillna(df_copy['Premis Desc'].mode()[0])

# %%
df['Premis Desc'].value_counts().head()
# Out:
# Premis Desc
# STREET                                          246970
# SINGLE FAMILY DWELLING                          160348
# MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)    116039
# PARKING LOT                                      66334
# OTHER BUSINESS                                   45763
# Name: count, dtype: int64

# %%
df_copy[['Vict Age']]
# Out:
#         Vict Age
# 0              0
# 1             47
# 2             19
# 3             19
# 4             28
# ...          ...
# 963001        44
# 963002        80
# 963003         0
# 963004         0
# 963005        70
#
# [963006 rows x 1 columns]

# %%
df_copy['Vict Age'] = df_copy['Vict Age'].apply(lambda x: x if x > 0 and x < 100 else np.nan)

# %%
df_copy['Vict Age'] = df_copy['Vict Age'].fillna(df_copy['Vict Age'].median())

# %%
df_copy[['Vict Sex']]
# Out:
#        Vict Sex
# 0             M
# 1             M
# 2             X
# 3             M
# 4             M
# ...         ...
# 963001        F
# 963002        F
# 963003        X
# 963004        X
# 963005        F
#
# [963006 rows x 1 columns]

# %%
df_copy['Vict Sex'] = df_copy['Vict Sex'].fillna('X')

# %%
df_copy['Vict Sex'].unique()
# Out:
# <StringArray>
# ['M', 'X', 'F', 'H', '-']
# Length: 5, dtype: str

# %%
df_copy['Vict Sex'] = df_copy['Vict Sex'].replace('-', np.nan)

# %%
df_copy['Vict Sex'] = df_copy['Vict Sex'].replace('H', 'X')

# %%
df_copy['Vict Sex'].unique()
# Out:
# <StringArray>
# ['M', 'X', 'F', nan]
# Length: 4, dtype: str

# %%
df_copy['Vict Sex'] = df_copy['Vict Sex'].fillna('X')

# %%
df_copy['Vict Sex'].unique()
# Out:
# <StringArray>
# ['M', 'X', 'F']
# Length: 3, dtype: str

# %% [markdown]
# ### ENCODING

# %%
df_copy['Vict Sex'] = df_copy['Vict Sex'].map({'M': 1, 'F': 0, 'X': 2})

# %%
df_copy.head()
# Out:
#    AREA NAME  Rpt Dist No                               Crm Cd Desc  Vict Age  \
# 0   Wilshire          784                          VEHICLE - STOLEN      37.0
# 1    Central          182                     BURGLARY FROM VEHICLE      47.0
# 2  Southwest          356                             BIKE - STOLEN      19.0
# 3   Van Nuys          964  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)      19.0
# 4  Hollywood          666                         THEFT OF IDENTITY      28.0
#
#    Vict Sex Vict Descent                                   Premis Desc  \
# 0         1            O                                        STREET
# 1         1            O             BUS STOP/LAYOVER (ALSO QUERY 124)
# 2         2            X  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 3         1            O                                CLOTHING STORE
# 4         1            H                                      SIDEWALK
#
# ...

# %%
df_copy = pd.get_dummies(df_copy, columns=['AREA NAME'], dtype=int)

# %%
df_copy.head()
# Out:
#    Rpt Dist No                               Crm Cd Desc  Vict Age  Vict Sex  \
# 0          784                          VEHICLE - STOLEN      37.0         1
# 1          182                     BURGLARY FROM VEHICLE      47.0         1
# 2          356                             BIKE - STOLEN      19.0         2
# 3          964  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)      19.0         1
# 4          666                         THEFT OF IDENTITY      28.0         1
#
#   Vict Descent                                   Premis Desc  Weapon Used Cd  \
# 0            O                                        STREET           500.0
# 1            O             BUS STOP/LAYOVER (ALSO QUERY 124)           500.0
# 2            X  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)           500.0
# 3            O                                CLOTHING STORE           500.0
# 4            H                                      SIDEWALK           500.0
#
# ...

# %%
df_copy['Premis Desc'].nunique()
# Out:
# 306

# %%
top_premis = df_copy['Premis Desc'].value_counts().nlargest(20).index

df_copy['Premis Desc'] = df_copy['Premis Desc'].apply(
    lambda x: x if x in top_premis else 'OTHER'
)

#One-copyhot encode
df_copy = pd.get_dummies(df_copy, columns=['Premis Desc'], dtype=int)

# %%
df_copy.head()
# Out:
#    Rpt Dist No                               Crm Cd Desc  Vict Age  Vict Sex  \
# 0          784                          VEHICLE - STOLEN      37.0         1
# 1          182                     BURGLARY FROM VEHICLE      47.0         1
# 2          356                             BIKE - STOLEN      19.0         2
# 3          964  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)      19.0         1
# 4          666                         THEFT OF IDENTITY      28.0         1
#
#   Vict Descent  Weapon Used Cd                  Weapon Desc      LAT  \
# 0            O           500.0  UNKNOWN WEAPON/OTHER WEAPON  34.0375
# 1            O           500.0  UNKNOWN WEAPON/OTHER WEAPON  34.0444
# 2            X           500.0  UNKNOWN WEAPON/OTHER WEAPON  34.0210
# 3            O           500.0  UNKNOWN WEAPON/OTHER WEAPON  34.1576
# 4            H           500.0  UNKNOWN WEAPON/OTHER WEAPON  34.0944
#
#         LON    year  ...  Premis Desc_OTHER RESIDENCE  \
# ...

# %%
df_copy['Weapon Desc'].nunique()
# Out:
# 79

# %%
df_copy['Crm Cd Desc'].nunique()
# Out:
# 139

# %%
df_copy.drop(['Weapon Desc'], axis=1, inplace=True)

# %%
df_copy.head()
# Out:
#    Rpt Dist No                               Crm Cd Desc  Vict Age  Vict Sex  \
# 0          784                          VEHICLE - STOLEN      37.0         1
# 1          182                     BURGLARY FROM VEHICLE      47.0         1
# 2          356                             BIKE - STOLEN      19.0         2
# 3          964  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)      19.0         1
# 4          666                         THEFT OF IDENTITY      28.0         1
#
#   Vict Descent  Weapon Used Cd      LAT       LON    year  month  ...  \
# 0            O           500.0  34.0375 -118.3506  2020.0    1.0  ...
# 1            O           500.0  34.0444 -118.2628  2020.0    8.0  ...
# 2            X           500.0  34.0210 -118.3002  2020.0    4.0  ...
# 3            O           500.0  34.1576 -118.4387  2020.0   10.0  ...
# 4            H           500.0  34.0944 -118.3277  2022.0    1.0  ...
#
#    Premis Desc_OTHER RESIDENCE  Premis Desc_PARK/PLAYGROUND  \
# ...

# %%
df_copy['Vict Descent'].value_counts()
# Out:
# Vict Descent
# H    289523
# X    231919
# W    193742
# B    132945
# O     75549
# A     20828
# K      5443
# F      4338
# C      4039
# J      1417
# V      1071
# I       936
# Z       506
# P       265
# U       207
# D        84
# G        69
# L        69
# S        54
# -         2
# Name: count, dtype: int64

# %%
import numpy as np

df_copy['Vict Descent'] = df_copy['Vict Descent'].replace('-', np.nan)

df_copy['Vict Descent'] = df_copy['Vict Descent'].fillna('X')

# %%
top_desc = df_copy['Vict Descent'].value_counts().nlargest(8).index

df_copy['Vict Descent'] = df_copy['Vict Descent'].apply(
    lambda x: x if x in top_desc else 'OTHER'
)

# %%
df_copy = pd.get_dummies(df_copy, columns=['Vict Descent'], dtype=int)

# %%
df_copy.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 963006 entries, 0 to 963005
# Data columns (total 62 columns):
#  #   Column                                                    Non-Null Count   Dtype
# ---  ------                                                    --------------   -----
#  0   Rpt Dist No                                               963006 non-null  int64
#  1   Crm Cd Desc                                               963006 non-null  str
#  2   Vict Age                                                  963006 non-null  float64
#  3   Vict Sex                                                  963006 non-null  int64
#  4   Weapon Used Cd                                            963006 non-null  float64
#  5   LAT                                                       963006 non-null  float64
#  6   LON                                                       963006 non-null  float64
#  7   year                                                      963006 non-null  float64
# ...

# %% [markdown]
# ### MODEL TRAINING

# %%
##independent and DEpendent feature 
x= df_copy.drop(['Crm Cd Desc'], axis=1)
y= df_copy['Crm Cd Desc']

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()
y= le.fit_transform(df_copy['Crm Cd Desc'])

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42
)

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(
    n_estimators=100,
    max_depth=20,
    random_state=42,
    n_jobs=-1
)

model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_jobs=-1, random_state=42)

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report

print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.4701716493078992
#               precision    recall  f1-score   support
#
#            0       0.91      0.02      0.04       521
#            1       0.93      0.29      0.45       224
#            2       0.50      0.72      0.59     10702
#            3       0.00      0.00      0.00       972
#            4       0.51      0.72      0.59     15014
#            5       0.00      0.00      0.00        43
#            6       0.58      0.32      0.42       478
#            7       0.33      0.00      0.00       863
#            9       0.00      0.00      0.00         2
#           10       0.00      0.00      0.00         1
#           11       0.56      0.05      0.09      1609
#           12       0.00      0.00      0.00         2
#           13       0.00      0.00      0.00        26
#           14       0.83      0.16      0.28        91
#           15       0.52      0.04      0.08      2864
#           16       0.00      0.00      0.00         3
# ...
